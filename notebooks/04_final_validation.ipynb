# %% [markdown]
# # 04 Final Validation
#
# **Owner Role:** Shared by all members
#
# **Purpose:** Validate final predictions, submission format, methodology notes, and reproducibility before competition submission.
#
# ## TODO Checklist
#
# - [ ] Confirm final model inputs and prediction file version.
# - [ ] Validate required submission columns and row counts.
# - [ ] Run sanity checks on prediction ranges and outlet coverage.
# - [ ] Record final decisions in `reports/decision_log.md`.
